# %%
from image_scrape_utils import *
# Out:
# /home/james/Documents/Projects/humanchessplayer2/chessimage/scrape_test.py:18: RuntimeWarning: invalid value encountered in divide
#   res = img*np.expand_dims((np.abs(img[:,:,0]/img[:,:,1]-1) < thresh-1),-1)
# /home/james/Documents/Projects/humanchessplayer2/chessimage/scrape_test.py:19: RuntimeWarning: invalid value encountered in divide
#   res = res*np.expand_dims((np.abs(img[:,:,0]/img[:,:,2]-1) < thresh-1),-1)
# /home/james/Documents/Projects/humanchessplayer2/chessimage/scrape_test.py:20: RuntimeWarning: invalid value encountered in divide
#   res = res*np.expand_dims((np.abs(img[:,:,1]/img[:,:,2]-1) < thresh-1),-1)

# %%
import time
import chess
import matplotlib.pyplot as plt

time.sleep(5)
    
start = time.time()

board_img = capture_board(shift=True)
top_clock_img = capture_top_clock()
bot_clock_img = capture_bottom_clock()
w_notation_img = capture_white_notation()

capture_end = time.time()
clock_read_start = time.time()
our_time = read_clock(bot_clock_img)
opp_time = read_clock(top_clock_img)
clock_read_end = time.time()

our_turn = is_our_turn_from_clock(bot_clock_img)
white_turn = is_white_turn_from_notation(w_notation_img)


if our_turn == white_turn:
    bottom = "w"
else:
    bottom = "b"
turn_read_end = time.time()


fen = get_fen_from_image(board_img, bottom=bottom, turn=white_turn)    
end = time.time()
print(fen)
print(chess.Board(fen))
print(end-start)
print(capture_end-start)
print(clock_read_end - clock_read_start)
print(turn_read_end - clock_read_end)
print(end - turn_read_end)
print("Our time:", our_time)
print("Opp time:", opp_time)

plt.imshow(board_img)
# Out:
# removed background in 0.0346989631652832
# function evaluated in 0.031180858612060547
# 1r4k1/2p1qp1p/3p2pB/2p1b3/2Q1P3/1P5P/1rPR1PP1/3R2K1 w - - 0 1
# . r . . . . k .
# . . p . q p . p
# . . . p . . p B
# . . p . b . . .
# . . Q . P . . .
# . P . . . . . P
# . r P R . P P .
# . . . R . . K .
# 0.08280706405639648
# 0.013998985290527344
# 0.0014395713806152344
# 0.00019311904907226562
# 0.06714391708374023
# Our time: 43
# Opp time: 30

# %%
chess.Board(fen)
# Out:
# Board('1r4k1/2p1qp1p/3p2pB/2p1b3/2Q1P3/1P5P/1rPR1PP1/3R2K1 w - - 0 1')

# %%
check_fen_last_move_bottom(fen, board_img)
# Out:
# True

# %%
plt.imshow(remove_background_colours(board_img, thresh=1.1))

# %%
BOTTOM_CLOCK_Y
# Out:
# 742

# %%
import time
import numpy as np

# %%
time.sleep(3)
print(is_our_turn_from_clock())
# Out:
# False

# %%
import matplotlib.pyplot as plt

# %%
time.sleep(3)
im = SCREEN_CAPTURE.capture((BOTTOM_CLOCK_X,BOTTOM_CLOCK_Y, CLOCK_WIDTH, CLOCK_HEIGHT))
img= im[:,:,:3]
colours = img.reshape(-1,3)

# %%
plt.imshow(img)

# %%
has_red = (colours[:,1] > 1.1*colours[:,0]).any()

# %%
set([tuple(x) for x in colours])
# Out:
# {(77, 77, 77),
#  (78, 78, 78),
#  (79, 79, 79),
#  (80, 80, 80),
#  (81, 81, 81),
#  (82, 82, 82),
#  (83, 83, 83),
#  (84, 84, 84),
#  (85, 85, 85),
#  (86, 86, 86),
#  (87, 87, 87),
#  (88, 88, 88),
#  (89, 89, 89),
#  (90, 90, 90),
#  (91, 91, 91),
#  (92, 92, 92),
#  (93, 93, 93),
#  (94, 94, 94),
#  (96, 96, 96),
#  (98, 98, 98),
#  (99, 99, 99),
#  (100, 100, 100),
#  (101, 101, 101),
#  (102, 102, 102),
#  (103, 103, 103),
#  (104, 104, 104),
#  (105, 105, 105),
#  (106, 106, 106),
#  (107, 107, 107),
#  (108, 108, 108),
#  (110, 110, 110),
#  (111, 111, 111),
#  (113, 113, 113),
#  (115, 115, 115),
#  (116, 116, 116),
#  (118, 118, 118),
#  (120, 120, 120),
#  (121, 121, 121),
#  (122, 122, 122),
#  (123, 123, 123),
#  (124, 124, 124),
#  (125, 125, 125),
#  (126, 126, 126),
#  (127, 127, 127),
#  (128, 128, 128),
#  (129, 129, 129),
#  (131, 131, 131),
#  (132, 132, 132),
#  (133, 133, 133),
#  (134, 134, 134),
#  (135, 135, 135),
#  (136, 136, 136),
#  (138, 138, 138),
#  (139, 139, 139),
#  (140, 140, 140),
#  (141, 141, 141),
#  (143, 143, 143),
#  (145, 145, 145),
#  (146, 146, 146),
#  (147, 147, 147),
#  (148, 148, 148),
#  (150, 150, 150),
#  (152, 152, 152),
#  (154, 154, 154),
#  (155, 155, 155),
#  (156, 156, 156),
#  (157, 157, 157),
#  (158, 158, 158),
#  (159, 159, 159),
#  (160, 160, 160),
#  (161, 161, 161),
#  (163, 163, 163),
#  (164, 164, 164),
#  (165, 165, 165),
#  (166, 166, 166),
#  (167, 167, 167),
#  (168, 168, 168),
#  (169, 169, 169),
#  (170, 170, 170),
#  (171, 171, 171),
#  (173, 173, 173),
#  (174, 174, 174),
#  (175, 175, 175),
#  (179, 179, 179),
#  (180, 180, 180),
#  (181, 181, 181),
#  (182, 182, 182),
#  (184, 184, 184),
#  (185, 185, 185),
#  (187, 187, 187),
#  (189, 189, 189),
#  (190, 190, 190),
#  (191, 191, 191),
#  (192, 192, 192),
#  (193, 193, 193),
#  (195, 195, 195),
#  (196, 196, 196),
#  (199, 199, 199),
#  (200, 200, 200),
#  (201, 201, 201),
#  (202, 202, 202),
#  (203, 203, 203),
#  (204, 204, 204),
#  (205, 205, 205),
#  (208, 208, 208),
#  (210, 210, 210),
#  (211, 211, 211),
#  (212, 212, 212),
#  (213, 213, 213),
#  (214, 214, 214),
#  (215, 215, 215),
#  (216, 216, 216),
#  (217, 217, 217),
#  (218, 218, 218),
#  (219, 219, 219),
#  (220, 220, 220),
#  (221, 221, 221),
#  (222, 222, 222),
#  (223, 223, 223),
#  (224, 224, 224),
#  (226, 226, 226),
#  (228, 228, 228),
#  (229, 229, 229),
#  (230, 230, 230),
#  (231, 231, 231),
#  (232, 232, 232),
#  (233, 233, 233),
#  (234, 234, 234),
#  (235, 235, 235),
#  (237, 237, 237),
#  (238, 238, 238),
#  (239, 239, 239),
#  (240, 240, 240),
#  (241, 241, 241),
#  (242, 242, 242),
#  (243, 243, 243),
#  (244, 244, 244),
#  (245, 245, 245),
#  (246, 246, 246),
#  (247, 247, 247),
#  (248, 248, 248),
#  (249, 249, 249),
#  (250, 250, 250),
#  (251, 251, 251),
#  (252, 252, 252),
#  (253, 253, 253),
#  (254, 254, 254),
#  (255, 255, 255)}

# %%
has_red
# Out:
# True

# %%
# !python scrape_test.py
# Out:
# [] R
# [] N
# [] B
# [] K
# [] Q
# [] P
# [60] r
# [] n
# [] b
# [] k
# [] q
# [] p
# 0.0902407169342041

# %%
a = np.random.random((5,2,2))
b = np.random.random((3,2,2))

# %%
a
# Out:
# array([[[0.44354731, 0.50179784],
#         [0.71711982, 0.88292018]],
#
#        [[0.43212998, 0.73404655],
#         [0.52757514, 0.75735944]],
#
#        [[0.65994523, 0.25468961],
#         [0.72482907, 0.76481429]],
#
#        [[0.38246707, 0.31106965],
#         [0.82864031, 0.54309262]],
#
#        [[0.50545216, 0.38250079],
#         [0.16264507, 0.6393245 ]]])

# %%
b
# Out:
# array([[[0.71289048, 0.40064763],
#         [0.19115635, 0.27047006]],
#
#        [[0.26505368, 0.28038566],
#         [0.67471557, 0.34609142]],
#
#        [[0.41785048, 0.25339582],
#         [0.55156168, 0.7082813 ]]])

# %%
a_prime=  np.expand_dims(a,1)
b_prime = np.expand_dims(b,0)

# %%
c_prime = a_prime.sum(axis=(-1,-2)) * b_prime.sum(axis=(-1,-2))

# %%
c_prime.shape
# Out:
# (5, 3)

# %%
(a_prime * b_prime).sum(axis=(-1,-2)).shape
# Out:
# (5, 3)

# %%
d = c_prime.argmax(axis=0)

# %%
c_prime
# Out:
# array([[4.00940039, 3.98670016, 4.91536599],
#        [3.86090324, 3.83904377, 4.73331438],
#        [3.78713371, 3.7656919 , 4.64287586],
#        [3.25313947, 3.234721  , 3.98822008],
#        [2.661906  , 2.64683496, 3.26339128]])

# %%
np.where(c_prime[d][0]>3)
# Out:
# (array([0, 1, 2]),)

# %%
d
# Out:
# array([0, 0, 0])
